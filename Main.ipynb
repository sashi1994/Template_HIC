# %%
# %%capture 
import pandas as pd
from SRC.Utils.UnitConverter import UnitConverter
#from ATD import *
#from SEAT import *
from SRC.constants.Directory_MME import *
from SRC.Models.Simulation.Read_MME import *
from SRC.Utils.Graphics import *

# %%
Simulation_Test = Read_MME("/Users/sashikiranmadugula/Documents/Coding/MME").Simulation_Test_info()
# Out:
# Time: Time Channel found !!
# ATD: ATD_Left found !!
# ATD: ATD_Right found !!
# SLED Sled1 found !!
# SLED Sled2 found !!

# %% [markdown]
# # Pulse
# * First think to check

# %%
Graphics.plot(Simulation_Test['Time'].timeseries(),[Simulation_Test['Sled1'].Pulse()],title='Pulse vs Time',time_limit=(0,250))

# %% [markdown]
# # Plotting of ATD Parts
#
# ## Only options available are:
#
# - **Head**
# - **Chest**
# - **Pelvis**
#
# For each of these ATD parts, we capture comprehensive motion data across the following aspects:
#
# - **Acceleration**: Provides insight into the linear acceleration experienced by each part over time.
#
# - **Angular Velocity**: Reflects the rate of rotation or change in angular position for each ATD part.
#
# - **Coordinates**: Spatial data points that describe the position of each part in terms of x, y, and z axes, allowing us to track their movement and alignment.

# %% [markdown]
# ### Head ATD
# * Acceleration of Head
# * Angular velocity of Head

# %%
# Call acceleration if there's a valid object mapp
Graphics.plot(Simulation_Test['Time'].timeseries(),[Simulation_Test['ATD_Left'].Acceleration('Head')],title='Acceleration',time_limit=(150,250))
# Call angular velocity if there's a valid object mapp
Graphics.plot(Simulation_Test['Time'].timeseries(),[Simulation_Test['ATD_Left'].Angular_Velocity('Head')],title='Angular_Velocity',time_limit=(150,250))

# %% [markdown]
# ### Chest ATD
# * Acceleration of Chest
# * Angular velocity of Chest

# %%
# Call angular velocity if there's a valid object mapp
Graphics.plot(Simulation_Test['Time'].timeseries(),[Simulation_Test['ATD_Left'].Acceleration('Chest')],title='Acceleration',time_limit=(0,250))
# Call angular velocity if there's a valid object mapp
Graphics.plot(Simulation_Test['Time'].timeseries(),[Simulation_Test['ATD_Left'].Angular_Velocity('Chest')],title='Angular_Velocity',time_limit=(0,250))

# %% [markdown]
# ### Pelvis ATD
# * Acceleration of Pelvis
# * Angular velocity of Pelvis

# %%
# Call angular velocity if there's a valid object mapp
Graphics.plot(Simulation_Test['Time'].timeseries(),[Simulation_Test['ATD_Left'].Acceleration('Pelvis')],title='Acceleration',time_limit=(500,2500))
# Call angular velocity if there's a valid object mapp
Graphics.plot(Simulation_Test['Time'].timeseries(),[Simulation_Test['ATD_Left'].Angular_Velocity('Pelvis')],title='Angular_Velocity',time_limit=(500,2500))

# %% [markdown]
# ## Superposition of Plots
# # you can plot same ATD as superposition.
# * You can plot 2 ATDs or more as per your requirements.
# * If, you want to plot 2 ATDs please check the ATD is "found" in second cell.
# * Example: Graphics.plot([atd_objects['ATD_Left'].Acceleration('Head'),atd_objects['ATD_Right'].Acceleration('Head')],time_limit=(400,2500))

# %%
Graphics.plot(Simulation_Test['Time'].timeseries(),[Simulation_Test['ATD_Left'].Acceleration('Head'),Simulation_Test['ATD_Right'].Acceleration('Head')],time_limit=(0,250))

# %% [markdown]
# **Getting Number of ATDs and Sleds**

# %%
# %%capture
#ATD_1 = Get_ATD_Vector(Directory).ATD_Get_Nodes()
#Seat = Seat_Vector(Directory).Seat_Get_Nodes()

# %% [markdown]
# **Initial Condition visualization**

# %%
#Graphics(ATD_Info,ATD_1,Seat).Initial_condition_plot()
